# %%
import torch
from torch_geometric.datasets import QM9
from torch_geometric.data import DataLoader
import os

# %%
dataset = QM9(root=os.getcwd()+'/data/QM9')
# Out:
# ...
# Extracting /Users/kairos/fun/build2understand/autoencoder/data/QM9/raw/qm9_v3.zip
# Processing...
# Using a pre-processed version of the dataset. Please install 'rdkit' to alternatively process the raw data.
# Done!

# %%
dataset.data.pos
# Out:
# /Users/kairos/.pyenv/versions/3.11.0/lib/python3.11/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
# tensor([[-1.2700e-02,  1.0858e+00,  8.0000e-03],
#         [ 2.2000e-03, -6.0000e-03,  2.0000e-03],
#         [ 1.0117e+00,  1.4638e+00,  3.0000e-04],
#         ...,
#         [ 2.5159e+00, -1.1518e+00,  5.2740e-01],
#         [ 1.3700e-02,  1.1994e+00, -1.6802e+00],
#         [ 1.2607e+00, -1.2468e+00, -1.9068e+00]])
